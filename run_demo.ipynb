# %%
run demo.py
# Out:
# ./test_result\test_images\t1.txt
# Mission complete, it took 1.314s
#
# Recognition Result:
#
# 392
# 392
# 393
# ./test_result\test_images\t2.txt
# Mission complete, it took 3.300s
#
# Recognition Result:
#
# 10
# 4
# ./test_result\test_images\t3.txt
# Mission complete, it took 4.271s
#
# Recognition Result:
#
# 011
# 00013 6
# ./test_result\test_images\t4.txt
# Mission complete, it took 4.467s
#
# Recognition Result:
#
# ./test_result\test_images\t5.txt
# Mission complete, it took 2.131s
#
# Recognition Result:
#
# 3934
# 3952
# 3908
